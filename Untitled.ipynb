# %%
import argparse

import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.patches import Rectangle

from deepdrive_dataset.deepdrive_dataset_reader import DeepdriveDatasetReader
from deepdrive_dataset.deepdrive_versions import DEEPDRIVE_FOLDS, DEEPDRIVE_VERSIONS

# %%
'''
parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', type=int, help='Batch Size to use', default=4)
parser.add_argument('--fold_type', type=str, choices=DEEPDRIVE_FOLDS, default='train')
parser.add_argument('--version', type=str, default='100k', choices=DEEPDRIVE_VERSIONS)
FLAGS = parser.parse_args()
'''
# Out:
# "\nparser = argparse.ArgumentParser()\nparser.add_argument('--batch_size', type=int, help='Batch Size to use', default=4)\nparser.add_argument('--fold_type', type=str, choices=DEEPDRIVE_FOLDS, default='train')\nparser.add_argument('--version', type=str, default='100k', choices=DEEPDRIVE_VERSIONS)\nFLAGS = parser.parse_args()\n"

# %%
from easydict import EasyDict as edict
FLAGS = edict()
FLAGS.fold_type='train'
FLAGS.batch_size=32
FLAGS.version='100k'

# %%
reader = DeepdriveDatasetReader(batch_size=FLAGS.batch_size)
if FLAGS.fold_type == 'train':
    iterator = reader.load_train_data_bbox(FLAGS.version, False)
elif FLAGS.fold_type == 'val':
    iterator = reader.load_val_data_bbox(FLAGS.version, False)
elif FLAGS.fold_type == 'test':
    iterator = reader.load_test_data_bbox(FLAGS.version, False)
else:
    raise BaseException('Unknown fold type: {0}'.format(FLAGS.fold_type))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    out = sess.run(iterator)
    out_labels = DeepdriveDatasetReader.parsing_boundingboxes(None, 'labels')
    print(out, out_labels)
    out_dict = dict(zip(out_labels, out))

    # Visualize the output
    import math
    images = out_dict['image']
    fig_row = int(math.ceil(images.shape[0] / 2))
    fig_col = int(math.ceil(images.shape[0] / 2))
    fig_col = 2
    print(fig_row, fig_col)
    f, axarr = plt.subplots(nrows=fig_row, ncols=fig_col, figsize=(10, 50))
    for im_id in range(images.shape[0]):
        plt.sca(axarr[int(im_id/2), im_id % 2])
        plt.imshow(images[im_id, :])
        # Boundingbox order is ymin, xmin, ymax, xmax
        for box in out_dict['bboxes'][im_id, :]:
            rect = Rectangle(
                xy=(box[1], box[0]), width=box[3] - box[1], height=box[2] - box[0], fill=False)
            axarr[int(im_id/2), im_id % 2].add_patch(rect)

        #
        axarr[int(im_id/2), im_id % 2].set_xticks([])
        axarr[int(im_id/2), im_id % 2].set_yticks([])
        axarr[int(im_id/2), im_id % 2].set_ylabel('Batch-Id: {0}'.format(im_id))
        axarr[int(im_id/2), im_id % 2].set_xlabel(str(out_dict['image_ids'][im_id]))
    plt.show()
# Out:
# (array([[[[ 92, 172, 223],
#          [ 92, 172, 223],
#          [ 92, 172, 223],
#          ...,
#          [ 13,  13,  23],
#          [ 13,  13,  23],
#          [ 13,  13,  23]],
#
#         [[ 89, 169, 220],
#          [ 89, 169, 220],
#          [ 89, 169, 220],
#          ...,
#          [ 13,  13,  23],
#          [ 13,  13,  23],
#          [ 13,  13,  23]],
#
#         [[ 96, 173, 225],
#          [ 96, 173, 225],
#          [ 96, 173, 225],
#          ...,
#          [ 13,  13,  23],
#          [ 13,  13,  23],
#          [ 13,  13,  23]],
#
#         ...,
#
#         [[ 20,  33,  42],
#          [ 20,  33,  42],
#          [ 20,  33,  42],
#          ...,
#          [ 16,  25,  32],
#          [ 16,  25,  32],
#          [ 16,  25,  32]],
#
#         [[ 20,  33,  42],
#          [ 20,  33,  42],
#          [ 20,  33,  42],
#          ...,
#          [ 16,  25,  32],
#          [ 16,  25,  32],
#          [ 16,  25,  32]],
#
#         [[ 20,  33,  42],
#          [ 20,  33,  42],
#          [ 20,  33,  42],
#          ...,
#          [ 16,  25,  32],
#          [ 16,  25,  32],
#          [ 16,  25,  32]]],
#
#
#        [[[158, 202, 237],
#          [158, 202, 237],
#          [157, 202, 235],
#          ...,
#          [160, 219, 249],
#          [160, 219, 249],
#          [160, 219, 249]],
#
#         [[158, 202, 237],
#          [158, 203, 236],
#          [157, 202, 235],
#          ...,
#          [160, 219, 249],
#          [160, 219, 249],
#          [160, 219, 249]],
#
#         [[157, 202, 235],
#          [157, 202, 233],
#          [156, 201, 232],
#          ...,
#          [160, 219, 249],
#          [160, 219, 249],
#          [160, 219, 249]],
#
#         ...,
#
#         [[ 14,  28,  31],
#          [ 12,  26,  29],
#          [  9,  23,  26],
#          ...,
#          [ 11,  21,  30],
#          [ 11,  21,  30],
#          [ 11,  21,  30]],
#
#         [[  7,  21,  22],
#          [  4,  18,  19],
#          [  1,  15,  16],
#          ...,
#          [ 13,  22,  29],
#          [ 13,  22,  29],
#          [ 14,  23,  30]],
#
#         [[  4,  18,  19],
#          [  2,  16,  17],
#          [  0,  13,  14],
#          ...,
#          [ 14,  23,  30],
#          [ 14,  23,  30],
#          [ 15,  24,  31]]],
#
#
#        [[[144, 177, 212],
#          [144, 177, 212],
#          [144, 177, 212],
#          ...,
#          [  7,   6,  11],
#          [  7,   6,  11],
#          [  7,   6,  11]],
#
#         [[144, 177, 212],
#          [144, 177, 212],
#          [144, 177, 212],
#          ...,
#          [  7,   6,  11],
#          [  7,   6,  11],
#          [  7,   6,  11]],
#
#         [[144, 177, 212],
#          [144, 177, 212],
#          [144, 177, 212],
#          ...,
#          [  7,   6,  11],
#          [  7,   6,  11],
#          [  7,   6,  11]],
#
#         ...,
#
#         [[ 23,  27,  36],
#          [ 23,  27,  36],
#          [ 23,  27,  36],
#          ...,
#          [ 12,  12,  14],
#          [ 12,  12,  14],
#          [ 12,  12,  14]],
#
#         [[ 24,  28,  37],
#          [ 24,  28,  37],
#          [ 24,  28,  37],
#          ...,
#          [ 11,  11,  13],
#          [ 11,  11,  13],
#          [ 11,  11,  13]],
#
#         [[ 24,  28,  37],
#          [ 24,  28,  37],
#          [ 24,  28,  37],
#          ...,
#          [ 14,  14,  16],
#          [ 15,  15,  17],
#          [ 15,  15,  17]]],
#
#
#        ...,
#
#
#        [[[148, 204, 239],
#          [148, 204, 239],
#          [148, 204, 239],
#          ...,
#          [ 81,  99,  75],
#          [ 82, 100,  74],
#          [ 83, 101,  75]],
#
#         [[148, 204, 239],
#          [148, 204, 239],
#          [148, 204, 239],
#          ...,
#          [ 80,  98,  72],
#          [ 81,  99,  73],
#          [ 82, 100,  74]],
#
#         [[148, 204, 239],
#          [148, 204, 239],
#          [148, 204, 239],
#          ...,
#          [ 80,  99,  71],
#          [ 82, 101,  73],
#          [ 82, 101,  73]],
#
#         ...,
#
#         [[ 78,  89,  91],
#          [ 77,  88,  90],
#          [ 75,  86,  88],
#          ...,
#          [118, 128, 127],
#          [118, 128, 127],
#          [118, 128, 127]],
#
#         [[ 79,  90,  92],
#          [ 77,  88,  90],
#          [ 74,  85,  87],
#          ...,
#          [119, 129, 128],
#          [119, 129, 128],
#          [119, 129, 128]],
#
#         [[ 80,  91,  93],
#          [ 77,  88,  90],
#          [ 74,  85,  87],
#          ...,
#          [119, 129, 128],
#          [119, 129, 128],
#          [119, 129, 128]]],
#
#
#        [[[106, 151, 182],
#          [ 92, 137, 168],
#          [ 96, 141, 172],
#          ...,
#          [ 70,  80,  79],
#          [ 70,  80,  79],
#          [ 70,  80,  79]],
#
#         [[106, 151, 182],
#          [ 92, 137, 168],
#          [ 96, 141, 172],
#          ...,
#          [ 70,  80,  79],
#          [ 70,  80,  79],
#          [ 70,  80,  79]],
#
#         [[107, 151, 180],
#          [ 93, 137, 166],
#          [ 96, 141, 172],
#          ...,
#          [ 70,  80,  79],
#          [ 70,  80,  79],
#          [ 70,  80,  79]],
#
#         ...,
#
#         [[ 30,  41,  43],
#          [ 30,  41,  43],
#          [ 30,  41,  43],
#          ...,
#          [ 32,  50,  50],
#          [ 32,  50,  50],
#          [ 32,  50,  50]],
#
#         [[ 30,  41,  43],
#          [ 30,  41,  43],
#          [ 30,  41,  43],
#          ...,
#          [ 32,  50,  50],
#          [ 32,  50,  50],
#          [ 32,  50,  50]],
#
#         [[ 30,  41,  43],
#          [ 30,  41,  43],
#          [ 30,  41,  43],
#          ...,
#          [ 32,  50,  50],
#          [ 32,  50,  50],
#          [ 32,  50,  50]]],
#
#
#        [[[ 29,  40,  46],
#          [ 26,  37,  43],
#          [ 25,  36,  42],
#          ...,
#          [ 78,  80,  66],
#          [140, 142, 131],
#          [163, 166, 155]],
#
#         [[ 91, 102, 108],
#          [ 88,  99, 105],
#          [ 88,  99, 105],
#          ...,
#          [149, 151, 137],
#          [175, 177, 166],
#          [155, 158, 147]],
#
#         [[151, 162, 168],
#          [149, 160, 166],
#          [149, 160, 166],
#          ...,
#          [165, 167, 153],
#          [139, 141, 130],
#          [ 87,  90,  79]],
#
#         ...,
#
#         [[ 60,  71,  73],
#          [ 60,  71,  73],
#          [ 60,  71,  73],
#          ...,
#          [ 15,  26,  32],
#          [ 15,  26,  32],
#          [ 15,  26,  32]],
#
#         [[ 57,  68,  70],
#          [ 57,  68,  70],
#          [ 57,  68,  70],
#          ...,
#          [ 15,  26,  32],
#          [ 15,  26,  32],
#          [ 15,  26,  32]],
#
#         [[ 55,  66,  68],
#          [ 55,  66,  68],
#          [ 55,  66,  68],
#          ...,
#          [ 15,  26,  32],
#          [ 15,  26,  32],
#          [ 15,  26,  32]]]], dtype=uint8), array([[[3.10181122e+02, 1.91646713e+02, 3.76612823e+02, 3.00035278e+02],
#         [3.10181122e+02, 5.88488770e+02, 3.78361023e+02, 6.75898926e+02],
#         [3.10181122e+02, 2.77308655e+02, 3.60878998e+02, 3.31502930e+02],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[2.99699890e+02, 6.44759766e+02, 3.11849884e+02, 6.60959778e+02],
#         [3.02399902e+02, 6.24509766e+02, 3.13199890e+02, 6.36659790e+02],
#         [3.01049896e+02, 6.32609802e+02, 3.13199890e+02, 6.46109802e+02],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[1.99184570e+02, 9.01681006e-01, 5.06654114e+02, 3.66779388e+02],
#         [4.11477814e+02, 1.06677600e+03, 6.82579956e+02, 1.27836792e+03],
#         [3.17804291e+02, 7.75837097e+02, 3.75110443e+02, 8.77224854e+02],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[1.59133347e+02, 5.89408691e+02, 1.67943024e+02, 6.02133789e+02],
#         [1.68921875e+02, 5.48296936e+02, 1.94372025e+02, 6.07028015e+02],
#         [7.69097977e+01, 7.09807495e+02, 1.15085014e+02, 7.74411743e+02],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[2.39796570e+02, 4.57993134e+02, 2.52976227e+02, 4.87647369e+02],
#         [2.43091476e+02, 4.26142303e+02, 2.62860962e+02, 4.79959229e+02],
#         [2.38698257e+02, 4.87647369e+02, 2.81532166e+02, 5.08515167e+02],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[1.71378952e+02, 3.64244202e+02, 2.02073685e+02, 3.75754730e+02],
#         [2.17421051e+02, 5.68875793e+02, 2.44278946e+02, 5.79107361e+02],
#         [1.72657898e+02, 3.78312622e+02, 2.02073685e+02, 3.88544189e+02],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]],
#       dtype=float32), array([[8, 8, 8, ..., 0, 0, 0],
#        [8, 8, 8, ..., 0, 0, 0],
#        [1, 8, 1, ..., 0, 0, 0],
#        ...,
#        [3, 3, 3, ..., 0, 0, 0],
#        [8, 8, 8, ..., 0, 0, 0],
#        [2, 2, 2, ..., 0, 0, 0]]), array([b'8991f623-dcc1ccea', b'72b9a00e-f0f15f80', b'50b115d6-4b08a666',
#        b'451d9692-ffcd17f6', b'605740bd-27f9f47a', b'0cbc4cff-a698f534',
#        b'149efa88-df78e615', b'7b98a859-a9424dc2', b'37d449a3-9114cdef',
#        b'05ba7f6a-61346008', b'11ded96e-22cedf76', b'4c115e0c-80c4dc52',
#        b'50cb34ee-4ffbdb0b', b'5305169c-6a157451', b'ab441b42-238fa42c',
#        b'529762d9-240c2be2', b'6d5c1066-c69f196f', b'080a57f6-ac5a5542',
#        b'98a24ff9-5cda348c', b'0514a4f5-d88db8b5', b'11035230-3b3d1ded',
#        b'631e93e3-6175e30b', b'af8c093b-89bcbe5d', b'5c47d8b6-ec22e053',
#        b'672eee37-49d2b7ab', b'39964421-abb6de3b', b'a1c69dc8-e0da656c',
#        b'1a2f950b-6289c313', b'168f94e5-b4f13f52', b'3a2c6873-3d71ff88',
#        b'a3e68103-ef5316c2', b'951afd53-32e8ba6c'], dtype=object), array([[1492984, 1492985, 1492986, ...,       0,       0,       0],
#        [1244781, 1244782, 1244783, ...,       0,       0,       0],
#        [ 874164,  874165,  874166, ...,       0,       0,       0],
#        ...,
#        [ 634491,  634492,  634493, ...,       0,       0,       0],
#        [1780207, 1780208, 1780209, ...,       0,       0,       0],
#        [1614829, 1614830, 1614831, ...,       0,       0,       0]]), array([[1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720],
#        [1280,  720]])) ('image', 'bboxes', 'bbox_labels', 'image_ids', 'box_ids', 'image_shape')
# 16 2
